# %%
# Import dependencies
import numpy as np
import pandas as pd

# %%
# Read the data
df = pd.read_csv("sample_load_weather_data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-69b534f3cd92> in <module>()
#       1 # Read the data
# ----> 2 df = pd.read_csv("sample_load_weather_data.csv")
#
# NameError: name 'pd' is not defined

# %%
df = pd.read_csv("CleanTrainData.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d99596544ec6> in <module>()
# ----> 1 df = pd.read_csv("CleanTrainData.csv")
#
# NameError: name 'pd' is not defined

# %%
encoded_data = pd.get_dummies(df)
encoded_data.head()
# Out:
#    Unnamed: 0  daycode  month  holidays      load  temp  cdd  hdd  season_F  \
# 0           0        0      1         1  1.108011    70    5    0         0
# 1           1        1      1         0  1.255454    67    2    0         0
# 2           2        2      1         1  1.074134    70    5    0         0
# 3           3        3      1         1  1.328308    52    0    8         0
# 4           4        4      1         1  1.222549    56    0    4         0
#
#    season_S          ...            season_W  weather_type_cold  \
# 0         0          ...                   1                  0
# 1         0          ...                   1                  0
# 2         0          ...                   1                  0
# 3         0          ...                   1                  1
# 4         0          ...                   1                  1
#
#    weather_type_hot  weather_type_mild  hr_weather_type_cold  \
# ...

# %%
df_new = encoded_data.drop("Unnamed: 0", axis = 1, inplace=False)

# %%
df_new.head()
# Out:
#    daycode  month  holidays      load  temp  cdd  hdd  season_F  season_S  \
# 0        0      1         1  1.108011    70    5    0         0         0
# 1        1      1         0  1.255454    67    2    0         0         0
# 2        2      1         1  1.074134    70    5    0         0         0
# 3        3      1         1  1.328308    52    0    8         0         0
# 4        4      1         1  1.222549    56    0    4         0         0
#
#    season_Sp  season_W  weather_type_cold  weather_type_hot  \
# 0          0         1                  0                 0
# 1          0         1                  0                 0
# 2          0         1                  0                 0
# 3          0         1                  1                 0
# 4          0         1                  1                 0
#
#    weather_type_mild  hr_weather_type_cold  hr_weather_type_hot  \
# 0                  1                     0                    0
# ...

# %%
new_df = df_new.corr()
new_df = pd.DataFrame(new_df)
new_df
# Out:
#                             daycode     month  holidays      load      temp  \
# daycode                1.000000e+00  0.014480  0.093129 -0.059819 -0.009539
# month                  1.447961e-02  1.000000 -0.067880  0.202572  0.030262
# holidays               9.312928e-02 -0.067880  1.000000  0.050338  0.115480
# load                  -5.981932e-02  0.202572  0.050338  1.000000  0.673212
# temp                  -9.538702e-03  0.030262  0.115480  0.673212  1.000000
# cdd                    3.073322e-02  0.119510  0.096489  0.853974  0.938104
# hdd                    7.983650e-02  0.133614 -0.068046  0.046760 -0.635389
# season_F              -1.858977e-02  0.523459 -0.038759 -0.212952 -0.079746
# season_S               2.716271e-02  0.189016  0.059902  0.748135  0.656706
# season_Sp              3.553703e-19 -0.421402  0.075054 -0.214842 -0.006339
# season_W              -1.289610e-02 -0.231384 -0.105976 -0.398129 -0.625982
# ...

# %%
df_new.to_csv("dummies_df.csv")
