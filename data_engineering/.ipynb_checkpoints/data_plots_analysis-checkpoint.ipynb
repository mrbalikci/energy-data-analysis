# %% [markdown]
# ### Data Engineering
#
# In this part the data is analyzed for missing any values

# %%
# Dependencies

import pandas as pd
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# the_data.ipynb

# %%
# Read the data
df = pd.read_csv("..", "data"sample_load_weather_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-a685df0c3350> in <module>()
#       1 # Read the data
# ----> 2 df = pd.read_csv("data/sample_load_weather_data.csv")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
df.tail()
# Out:
#            date wkday  year  daycode  month  holidays season weather_type  \
# 350  2017-12-27   twt  2017        3     12         1      W         cold
# 351  2017-12-28   twt  2017        4     12         1      W         cold
# 352  2017-12-29   fri  2017        5     12         1      W         cold
# 353  2017-12-30   sat  2017        6     12         1      W         cold
# 354  2017-12-31   sun  2017        0     12         1      W         cold
#
#          load  temp hr_weather_type  cdd  hdd
# 350  1.812026    41           xcold    0   19
# 351  1.741627    43           xcold    0   17
# 352  1.323119    51            cold    0    9
# 353  1.056757    55            cold    0    5
# 354  1.546742    47           xcold    0   13

# %%
df.describe()
# Out:
#          year     daycode       month    holidays        load        temp  \
# count   355.0  355.000000  355.000000  355.000000  355.000000  355.000000
# mean   2017.0    3.000000    6.484507    0.966197    1.526779   75.754930
# std       0.0    2.011268    3.491986    0.180976    0.455645   11.632275
# min    2017.0    0.000000    1.000000    0.000000    0.768609   34.000000
# 25%    2017.0    1.000000    3.000000    1.000000    1.123627   69.000000
# 50%    2017.0    3.000000    6.000000    1.000000    1.449273   77.000000
# 75%    2017.0    5.000000   10.000000    1.000000    1.876555   85.000000
# max    2017.0    6.000000   12.000000    1.000000    2.602438   94.000000
#
#               cdd         hdd
# count  355.000000  355.000000
# mean    12.233803    0.811268
# std      8.865854    3.272188
# min      0.000000    0.000000
# 25%      4.000000    0.000000
# 50%     12.000000    0.000000
# 75%     20.000000    0.000000
# max     29.000000   26.000000

# %%
df["hr_weather_type"].unique()
# Out:
# array(['mild', 'cold', 'xcold', 'hot', 'xxhot', 'xhot'], dtype=object)

# %%
df['weather_type'].unique()
# Out:
# array(['mild', 'cold', 'hot'], dtype=object)

# %%
df_mild = df[df['hr_weather_type']=='xhot']
plt.scatter(df_mild['temp'], df_mild['load'])
plt.title("Temp vs Load")
plt.xlabel("Temps")
plt.ylabel("Loads")
plt.show()

# %%
plt.scatter(df['temp'], df['load'])

# %%
plt.show()

# %%
df.describe()
# Out:
#          year     daycode       month    holidays        load        temp  \
# count   355.0  355.000000  355.000000  355.000000  355.000000  355.000000
# mean   2017.0    3.000000    6.484507    0.966197    1.526779   75.754930
# std       0.0    2.011268    3.491986    0.180976    0.455645   11.632275
# min    2017.0    0.000000    1.000000    0.000000    0.768609   34.000000
# 25%    2017.0    1.000000    3.000000    1.000000    1.123627   69.000000
# 50%    2017.0    3.000000    6.000000    1.000000    1.449273   77.000000
# 75%    2017.0    5.000000   10.000000    1.000000    1.876555   85.000000
# max    2017.0    6.000000   12.000000    1.000000    2.602438   94.000000
#
#               cdd         hdd
# count  355.000000  355.000000
# mean    12.233803    0.811268
# std      8.865854    3.272188
# min      0.000000    0.000000
# 25%      4.000000    0.000000
# 50%     12.000000    0.000000
# 75%     20.000000    0.000000
# max     29.000000   26.000000

# %%
df.corr()
# Out:
#           year   daycode     month  holidays      load      temp       cdd  \
# year       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# daycode    NaN  1.000000  0.014480  0.093129 -0.059819 -0.009539  0.030733
# month      NaN  0.014480  1.000000 -0.067880  0.202572  0.030262  0.119510
# holidays   NaN  0.093129 -0.067880  1.000000  0.050338  0.115480  0.096489
# load       NaN -0.059819  0.202572  0.050338  1.000000  0.673212  0.853974
# temp       NaN -0.009539  0.030262  0.115480  0.673212  1.000000  0.938104
# cdd        NaN  0.030733  0.119510  0.096489  0.853974  0.938104  1.000000
# hdd        NaN  0.079837  0.133614 -0.068046  0.046760 -0.635389 -0.343077
#
#                hdd
# year           NaN
# daycode   0.079837
# month     0.133614
# holidays -0.068046
# load      0.046760
# temp     -0.635389
# cdd      -0.343077
# hdd       1.000000
